# %% [markdown]
# ##** What is 7 to the power of 4?**

# %%
7 ** 4
# Out:
# 2401

# %% [markdown]
# ## ** Split this string:**
#
# s = "Hi there Yogesh!"
# **into a list. **

# %%
s = "Hi there Yogesh!"
s.split()
# Out:
# ['Hi', 'there', 'Yogesh!']

# %% [markdown]
# ** Given the variables:**
#
# planet = "Earth"
# diameter = 12742
# ** Use .format() to print the following string: **

# %%
planet = "Earth"
diameter = 12742

print("The diameter of {} is {} kilometers.".format(planet, diameter))
# Out:
# The diameter of Earth is 12742 kilometers.

# %%
** Given this nested list, use indexing to grab the word "hello" **
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
# Out:
#   Cell In[7], line 1
#     ** Given this nested list, use indexing to grab the word "hello" **
#     ^
# SyntaxError: invalid syntax

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

lst[3][1][2][0]
# Out:
# 'hello'

# %% [markdown]
# ** Given this nested dictionary grab the word "hello". Be prepared, this will be annoying/tricky **

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %% [markdown]
# ** What is the main difference between a tuple and a list? **

# %% [markdown]
# List: Mutable
# Tuple: Immutable

# %% [markdown]
# ** Create a function that grabs the email website domain from a string in the form: **
#
#     user@domain.com
#
# **So for example, passing "user@domain.com" would return: domain.com**

# %%
def get_domain(email):
    return email.split('@')[1]

# Example
get_domain("user@domain.com")
# Out:
# 'domain.com'

# %%
fun1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fun1()
#
# NameError: name 'fun1' is not defined

# %%
def fun1(email):
    return email.split("@")[1]

# Example
fun1("user@domain.com")
# Out:
# 'domain.com'

# %% [markdown]
# ** Create a basic function that returns True if the word 'dog' is contained in the input string. Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization. **

# %%
def find_dog(text):
    return 'dog' in text.lower()

# Example
find_dog("My Dog is cute")
# Out:
# True

# %%
def findDog(text):
    return 'dog' in text.lower()

# %%
findDog('Is there a dog here?')
# Out:
# True

# %% [markdown]
# ** Create a function that counts the number of times the word "dog" occurs in a string. Again ignore edge cases. **

# %%
def count_dog(text):
    return text.lower().split().count('dog')

# Example
count_dog("Dog ran fast. dog is cute. I love my dog")
# Out:
# 3

# %%
countDog('This dog runs faster than the other dog dude!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 countDog('This dog runs faster than the other dog dude!')
#
# NameError: name 'countDog' is not defined

# %%
def countDog(text):
    return text.lower().count('dog')

# Example
countDog('This dog runs faster than the other dog dude!')
# Out:
# 2

# %% [markdown]
# ** Use lambda expressions and the filter() function to filter out words from a list that don't start with the letter 's'. For example:** seq = ['soup','dog','salad','cat','great'] should be filtered down to: ['soup','salad']

# %%
seq = ['soup','dog','salad','cat','great']

result = list(filter(lambda word: word.startswith('s'), seq))
result
# Out:
# ['soup', 'salad']

# %%
seq = ['soup','dog','salad','cat','great']

filtered_seq = list(filter(lambda word: word.startswith('s'), seq))
filtered_seq
# Out:
# ['soup', 'salad']

# %% [markdown]
# **You are driving a little too fast, and a police officer stops you. Write a function to return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket". If your speed is 60 or less, the result is "No Ticket". If speed is between 61 and 80 inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of the function) -- on your birthday, your speed can be 5 higher in all cases. **

# %%
def caught_speeding(speed, is_birthday):
    # On birthday, allow 5 extra mph
    if is_birthday:
        speed -= 5
    
    if speed <= 60:
        return "No Ticket"
    elif speed <= 80:
        return "Small Ticket"
    else:
        return "Big Ticket"

# Examples
caught_speeding(85, False)  # Not birthday
caught_speeding(85, True)   # Birthday
# Out:
# 'Small Ticket'

# %%
def caught_speeding(speed, is_birthday):
    pass

# %%
def caught_speeding(speed, is_birthday):
    # On birthday, allow 5 extra mph
    if is_birthday:
        speed -= 5
    
    if speed <= 60:
        return "No Ticket"
    elif speed <= 80:
        return "Small Ticket"
    else:
        return "Big Ticket"

# Example calls
caught_speeding(85, False)  # Output: 'Big Ticket'
caught_speeding(85, True)   # Output: 'Small Ticket'
# Out:
# 'Small Ticket'

# %%
caught_speeding(81,True)
# Out:
# 'Small Ticket'

# %%
caught_speeding(81,True)
# Out:
# 'Small Ticket'

# %%
caught_speeding(81,True)
# Out:
# 'Small Ticket'

# %% [markdown]
# Question
# Given a string print number num by extracting all the
# digits from the string as in string
# Print negative number if the first character in
# string is '-'
# eg.
# -123abcd should return -123,abcd456-->456,fdhfh78dsd89--->7889,
# -56dssd78-->-5678

# %%
def extract_number(s):
    # Check if first character is '-'
    negative = s[0] == '-'
    
    # Extract all digits
    digits = ''.join([ch for ch in s if ch.isdigit()])
    
    # Add negative sign if needed
    if negative:
        digits = '-' + digits
    
    return digits

# Example calls
print(extract_number('-123abcd'))      # Output: -123
print(extract_number('abcd456'))       # Output: 456
print(extract_number('fdhfh78dsd89'))  # Output: 7889
print(extract_number('-56dssd78'))     # Output: -5678
# Out:
# -123
# 456
# 7889
# -5678

# %% [markdown]
# Q2
# WAP to check whether a number is palindrome or not on following
# conditions.
# 1. take input number
# 2. add number and its reverse
# 3. check that number is palindrome or not,if not then sum and its reverse

# %%
def is_palindrome(num):
    return str(num) == str(num)[::-1]

def make_palindrome(num):
    while not is_palindrome(num):
        rev = int(str(num)[::-1])
        num += rev
    return num

# Take input from user
num = int(input("Enter a number: "))
result = make_palindrome(num)
print("Palindrome formed:", result)
# Out:
# Enter a number:  56
# Palindrome formed: 121

# %% [markdown]
# Write a python function to find and display the five
# digit number in which the first digit is two more than
# the second,the second digit is two more than the third,
# the fourth digit is two less than the third, and the
# last digit is two more than
# the fourth.The sum of the third,fourth and fifth digits
# equals the first.The sum of all the digits is 19

# %%
def find_five_digit_number():
    # Let the digits be a, b, c, d, e
    for c in range(0, 10):
        b = c + 2          # second digit
        a = b + 2          # first digit
        d = c - 2          # fourth digit
        e = d + 2          # fifth digit
        
        # Condition 1: sum of 3rd,4th,5th digits equals first
        if c + d + e != a:
            continue
        
        # Condition 2: sum of all digits is 19
        if a + b + c + d + e != 19:
            continue
        
        number = int(f"{a}{b}{c}{d}{e}")

# %% [markdown]
# def find_five_digit():

# %%
def find_five_digit():
    # Let the digits be a, b, c, d, e
    for c in range(0, 10):
        b = c + 2          # second digit
        a = b + 2          # first digit
        d = c - 2          # fourth digit
        e = d + 2          # fifth digit
        
        # Condition 1: sum of 3rd, 4th, 5th digits equals first
        if c + d + e != a:
            continue
        
        # Condition 2: sum of all digits is 19
        if a + b + c + d + e != 19:
            continue
        
        number = int(f"{a}{b}{c}{d}{e}")
        return number

# Example call
find_five_digit()
# Out:
# 75313
